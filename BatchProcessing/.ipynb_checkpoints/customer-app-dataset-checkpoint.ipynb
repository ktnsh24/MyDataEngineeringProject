# %% [markdown]
# # Install Faker Library

# %%
pip install Faker
# Out:
# Requirement already satisfied: Faker in /Users/ketansahu/opt/anaconda3/lib/python3.8/site-packages (8.1.1)
# Requirement already satisfied: python-dateutil>=2.4 in /Users/ketansahu/opt/anaconda3/lib/python3.8/site-packages (from Faker) (2.8.1)
# Requirement already satisfied: text-unidecode==1.3 in /Users/ketansahu/opt/anaconda3/lib/python3.8/site-packages (from Faker) (1.3)
# Requirement already satisfied: six>=1.5 in /Users/ketansahu/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.4->Faker) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Python Libraries

# %%
import pandas as pd
import numpy as np
from faker import Faker

# %% [markdown]
# # Create Fake Customers Dataset

# %%
fake = Faker()
n = 1000
faker_data = pd.DataFrame([[fake.name(), 
                            fake.state(),
                           fake.date_of_birth(minimum_age =18, maximum_age = 65)] 
            for _ in range(n)],
            columns=['customer_name', 'customer_location', 'customer_birth_date' ])
faker_data['customer_id'] = range(1, 1+len(faker_data))
faker_data.head(30)
# Out:
#              customer_name customer_location customer_birth_date  customer_id
# 0              Donna Jones           Indiana          1984-05-02            1
# 1           Steven Huffman           Alabama          1958-12-22            2
# 2              John Taylor              Utah          1959-09-05            3
# 3             Sarah Harris           Indiana          1982-02-03            4
# 4           Dustin Robbins            Alaska          1982-11-21            5
# 5             Robin Farmer           Florida          1981-03-09            6
# 6            Maurice Craig             Maine          1956-06-28            7
# 7         Victor Henderson          Nebraska          1999-07-23            8
# 8           Patricia Perry        California          1994-01-03            9
# 9        Robert Williamson    South Carolina          1972-06-05           10
# 10      Cassandra Williams       Mississippi          1978-02-28           11
# 11              Paul Burke            Hawaii          1971-04-19           12
# 12         Timothy Krueger          Oklahoma          1974-12-05           13
# 13              John Estes    South Carolina          1968-11-25           14
# 14            William Bass     New Hampshire          1993-10-01           15
# 15              Karen King            Oregon          1972-05-08           16
# 16       Michelle Delacruz          Missouri          2002-09-15           17
# 17             Jack Brooks          Missouri          1999-12-23           18
# 18               Amy Huang        Washington          1979-04-22           19
# 19             Mandy Lopez         Wisconsin          1963-11-21           20
# 20  Mrs. Elizabeth Chapman       Connecticut          1961-04-28           21
# 21           Linda Daniels             Maine          1972-04-23           22
# 22       Mr. William Kirby          Missouri          1998-02-03           23
# 23     Mrs. Casey Mitchell          Virginia          1959-11-18           24
# 24           Daniel Garcia     Massachusetts          2003-04-20           25
# 25          Natalie Knight              Utah          1988-04-05           26
# 26           Jennifer Snow        New Jersey          1982-02-14           27
# 27             Louis Singh            Hawaii          2001-12-20           28
# 28          Angela Salazar          Michigan          1999-02-06           29
# 29       Dr. Amber Hoffman          Oklahoma          1982-05-13           30

# %% [markdown]
# # Import App Dataset

# %%
filepath = "googleplaystore.csv" #Use your localpath
df = pd.read_csv(filepath ,encoding='utf-8')
col_name = ['app',  'category', 'rating', 'reviews', 'app_size', 'installs', 'app_type', 'price', 'content_rating', 'genres', 'last_updated', 'current_version', 'android_version']
df.columns = col_name
df.head(5)
# Out:
#                                                  app        category  rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    reviews app_size     installs app_type price content_rating  \
# 0      159      19M      10,000+     Free     0       Everyone
# 1      967      14M     500,000+     Free     0       Everyone
# 2    87510     8.7M   5,000,000+     Free     0       Everyone
# 3   215644      25M  50,000,000+     Free     0           Teen
# 4      967     2.8M     100,000+     Free     0       Everyone
#
#                       genres      last_updated     current_version  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#   android_version
# 0    4.0.3 and up
# 1    4.0.3 and up
# 2    4.0.3 and up
# 3      4.2 and up
# 4      4.4 and up

# %% [markdown]
# # Assign and Randomly Distribute customer_id to App Dataset

# %%
df["customer_id"] = np.random.randint(1, 1000, len(df))
df
# Out:
#                                                      app             category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                   Sya9a Maroc - FR               FAMILY
# 10835                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10836                             Parkinson Exercices FR              MEDICAL
# 10837                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10838      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        rating  reviews            app_size     installs app_type price  \
# 0         4.1      159                 19M      10,000+     Free     0
# 1         3.9      967                 14M     500,000+     Free     0
# 2         4.7    87510                8.7M   5,000,000+     Free     0
# 3         4.5   215644                 25M  50,000,000+     Free     0
# 4         4.3      967                2.8M     100,000+     Free     0
# ...       ...      ...                 ...          ...      ...   ...
# 10834     4.5       38                 53M       5,000+     Free     0
# 10835     5.0        4                3.6M         100+     Free     0
# 10836     NaN        3                9.5M       1,000+     Free     0
# 10837     4.5      114  Varies with device       1,000+     Free     0
# 10838     4.5   398307                 19M  10,000,000+     Free     0
#
#       content_rating                     genres      last_updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10834       Everyone                  Education     July 25, 2017
# 10835       Everyone                  Education      July 6, 2018
# 10836       Everyone                    Medical  January 20, 2017
# 10837     Mature 17+          Books & Reference  January 19, 2015
# 10838       Everyone                  Lifestyle     July 25, 2018
#
#           current_version     android_version  customer_id
# 0                   1.0.0        4.0.3 and up          131
# 1                   2.0.0        4.0.3 and up          349
# 2                   1.2.4        4.0.3 and up          464
# 3      Varies with device          4.2 and up          871
# 4                     1.1          4.4 and up          811
# ...                   ...                 ...          ...
# 10834                1.48          4.1 and up           17
# 10835                 1.0          4.1 and up          787
# 10836                 1.0          2.2 and up          728
# 10837  Varies with device  Varies with device          339
# 10838  Varies with device  Varies with device          905
#
# [10839 rows x 14 columns]

# %% [markdown]
# # Merge Customer Data and App Data

# %%
customer_app_data = df.merge(faker_data, on='customer_id', how='left')
customer_app_data
# Out:
#                                                      app             category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                   Sya9a Maroc - FR               FAMILY
# 10835                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10836                             Parkinson Exercices FR              MEDICAL
# 10837                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10838      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        rating  reviews            app_size     installs app_type price  \
# 0         4.1      159                 19M      10,000+     Free     0
# 1         3.9      967                 14M     500,000+     Free     0
# 2         4.7    87510                8.7M   5,000,000+     Free     0
# 3         4.5   215644                 25M  50,000,000+     Free     0
# 4         4.3      967                2.8M     100,000+     Free     0
# ...       ...      ...                 ...          ...      ...   ...
# 10834     4.5       38                 53M       5,000+     Free     0
# 10835     5.0        4                3.6M         100+     Free     0
# 10836     NaN        3                9.5M       1,000+     Free     0
# 10837     4.5      114  Varies with device       1,000+     Free     0
# 10838     4.5   398307                 19M  10,000,000+     Free     0
#
#       content_rating                     genres      last_updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10834       Everyone                  Education     July 25, 2017
# 10835       Everyone                  Education      July 6, 2018
# 10836       Everyone                    Medical  January 20, 2017
# 10837     Mature 17+          Books & Reference  January 19, 2015
# 10838       Everyone                  Lifestyle     July 25, 2018
#
#           current_version     android_version  customer_id      customer_name  \
# 0                   1.0.0        4.0.3 and up          131        Lisa Walker
# 1                   2.0.0        4.0.3 and up          349   Patrick Stephens
# 2                   1.2.4        4.0.3 and up          464  Danielle Sandoval
# 3      Varies with device          4.2 and up          871      Whitney Adams
# 4                     1.1          4.4 and up          811    Joseph Griffith
# ...                   ...                 ...          ...                ...
# 10834                1.48          4.1 and up           17  Michelle Delacruz
# 10835                 1.0          4.1 and up          787     Robert Bullock
# 10836                 1.0          2.2 and up          728       Cathy Howard
# 10837  Varies with device  Varies with device          339       William Ryan
# 10838  Varies with device  Varies with device          905      Tammy Johnson
#
#       customer_location customer_birth_date
# 0              Kentucky          1993-02-24
# 1                Hawaii          1963-11-01
# 2          North Dakota          1957-11-03
# 3               Arizona          1998-08-30
# 4            Washington          1965-11-25
# ...                 ...                 ...
# 10834          Missouri          2002-09-15
# 10835            Oregon          1968-05-13
# 10836         Minnesota          1984-02-05
# 10837              Iowa          1989-12-22
# 10838      Pennsylvania          1986-11-17
#
# [10839 rows x 17 columns]
