# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('max_colwidth', -1)
# Out:
# <style>.container { width:100% !important; }</style>
# <ipython-input-4-af59b17b2a7e>:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('max_colwidth', -1)

# %% [markdown]
# # Python Libraries

# %%
import pandas as pd
import os
import numpy as np
import pandas as pd
import datetime
import time
from datetime import datetime
import matplotlib.pyplot as plt
from collections import defaultdict

# %% [markdown]
# # Importing/Loading of Kaggle Google App Dataset

# %%
filepath = "/Users/ketansahu/Documents/DataEngineeringProject/GitHubRepo/googleplaystore.csv"
df = pd.read_csv(filepath ,encoding='utf-8')
col_name = ['app',  'category', 'rating', 'reviews', 'app_size', 'installs', 'app_type', 'price', 'content_rating', 'genres', 'last_updated', 'current_version', 'android_version']
df.columns = col_name

# %%
#Add 1000 Random user_id
df["user_id"] = np.random.randint(1, 1000, len(df))
#Add download date of today
#df["download_date"] = np.random.choice(pd.date_range('2020-01-01', '2021-01-01'), len(df))
df["download_date"] = pd.date_range('today', periods=len(df), freq='1S').normalize()
#reindex the column order
df = df.reindex(columns=['download_date', 'user_id', 'app',  'category', 'rating', 'reviews', 'app_size', 'installs', 'app_type', 'price', 'content_rating', 'genres', 'last_updated', 'current_version', 'android_version'])
#Sort the Dataframe based on the the download_date
df = df.sort_values('download_date')
#reset the index=row numbers
df = df.reset_index(drop =True)
df
# Out:
#       download_date  user_id  \
# 0     2021-03-28     35
# 1     2021-03-28     294
# 2     2021-03-28     675
# 3     2021-03-28     824
# 4     2021-03-28     591
# ...          ...     ...
# 10834 2021-03-28     318
# 10835 2021-03-28     426
# 10836 2021-03-28     98
# 10837 2021-03-28     761
# 10838 2021-03-28     342
#
#                                                              app  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook
# 1      Pyaterochka
# 2      Refreshing app Free application that can use deal coupons
# 3      Citi Mobile®
# 4      Amex Mobile
# ...            ...
# 10834  FK Senica
# 10835  FK Jablonec
# 10836  FK Dedinje BGD
# 10837  FK Events
# 10838  iHoroscope - 2018 Daily Horoscope & Astrology
#
#              category  rating  reviews            app_size     installs  \
# 0      ART_AND_DESIGN  4.1     159      19M                 10,000+
# 1      FOOD_AND_DRINK  3.1     8412     Varies with device  1,000,000+
# 2      FOOD_AND_DRINK  3.5     10741    41M                 1,000,000+
# 3      FINANCE         4.0     78306    46M                 5,000,000+
# 4      FINANCE         4.3     24729    32M                 1,000,000+
# ...        ...         ...       ...    ...                        ...
# 10834  SPORTS         NaN      0        13M                 10+
# 10835  SPORTS         NaN      2        26M                 50+
# 10836  SPORTS          5.0     36       2.6M                100+
# 10837  PRODUCTIVITY   NaN      0        18M                 5+
# 10838  LIFESTYLE       4.5     398307   19M                 10,000,000+
#
#       app_type price content_rating        genres       last_updated  \
# 0      Free     0     Everyone       Art & Design  January 7, 2018
# 1      Free     0     Everyone       Food & Drink  July 19, 2018
# 2      Free     0     Everyone       Food & Drink  July 23, 2018
# 3      Free     0     Everyone       Finance       July 31, 2018
# 4      Free     0     Everyone       Finance       August 3, 2018
# ...     ...    ..          ...           ...                  ...
# 10834  Free     0     Everyone       Sports        August 24, 2017
# 10835  Free     0     Everyone       Sports        February 27, 2018
# 10836  Free     0     Everyone       Sports        February 11, 2017
# 10837  Free     0     Teen           Productivity  June 27, 2018
# 10838  Free     0     Everyone       Lifestyle     July 25, 2018
#
#           current_version     android_version
# 0      1.0.0               4.0.3 and up
# 1      Varies with device  4.4 and up
# 2      5.2.2               4.2 and up
# 3      9.9.0               4.4 and up
# 4      6.7.0               5.0 and up
# ...      ...                      ...
# 10834  14                  4.1 and up
# 10835  1.0                 4.1 and up
# 10836  1.1                 4.0 and up
# 10837  7.17.2.1            5.0 and up
# 10838  Varies with device  Varies with device
#
# [10839 rows x 15 columns]

# %% [markdown]
# # App Details

# %%
#Assign app_id to each unique app in the dataset
df['app_id'] = df.groupby(['app']).ngroup()
df['app_id'] = df['app_id'].map(lambda q: q+500)

# %%
#Total unique app in the data set
df_app = df['app'].unique()
len(df_app)
# Out:
# 9659

# %% [markdown]
# # Fake User Details Dataset

# %%
from faker import Faker
fake = Faker()
n = 1000
faker_data = pd.DataFrame([[fake.name(), np.random.randint(14,65), fake.state()] for _ in range(n)],
     columns=['user_name', 'user_age', 'user_location'])
user_id = pd.factorize(faker_data.apply(tuple, axis=1))[0] + 1
faker_data.insert(loc=0, column='user_id', value=user_id)
faker_data.head(30)
# Out:
#     user_id        user_name  user_age user_location
# 0   1        Robert White     42        Ohio
# 1   2        Larry Roth       32        Indiana
# 2   3        Travis Barrett   35        California
# 3   4        Jamie Fisher     20        Minnesota
# 4   5        Adam Chaney      15        Connecticut
# 5   6        Jasmine Owen     57        Iowa
# 6   7        Margaret Gibson  57        Wyoming
# 7   8        Taylor Cook MD   43        Maine
# 8   9        Jessica Weber    40        Maine
# 9   10       Dillon Brady     36        Nevada
# 10  11       Courtney Bishop  44        Oklahoma
# 11  12       Brent Lawson     38        Indiana
# 12  13       John Wilson      15        Montana
# 13  14       Pamela Carlson   57        Nevada
# 14  15       Haley Goodwin    42        Maine
# 15  16       Tonya Wilson     26        Wisconsin
# 16  17       James Rhodes     46        Florida
# 17  18       David Brennan    59        California
# 18  19       Megan Rowe       15        Indiana
# 19  20       Alexis Barr      41        Arkansas
# 20  21       Richard Sanchez  48        Idaho
# 21  22       George Graham    51        Iowa
# 22  23       Shane Mcclain    18        Nebraska
# 23  24       Erika Benton     21        Nebraska
# 24  25       Lisa Salinas     61        Montana
# 25  26       Michael Green    14        Ohio
# 26  27       Alec Harris      45        Louisiana
# 27  28       Mark Cruz        56        Alabama
# 28  29       Jessica Nelson   57        Arizona
# 29  30       Adam Jennings    33        Florida

# %% [markdown]
# # Data Merge (Kaggle Google App Data + Fake User Details Data)

# %%
#Merge Faker data to kaggle data on left
users_app_data = df.merge(faker_data, on='user_id', how='left')
#Add time spent column
#users_app_data['time_spent_min'] = np.random.randint(90, 400, len(users_app_data))
users_app_data['user_details'] = users_app_data['user_name'] + ', ' + users_app_data['user_age'].astype(str) + ', ' + users_app_data['user_location']
users_app_data = users_app_data.drop(['user_name', 'user_age', 'user_location'], 1)
users_app_data
# Out:
#       download_date  user_id  \
# 0     2021-03-28     35
# 1     2021-03-28     294
# 2     2021-03-28     675
# 3     2021-03-28     824
# 4     2021-03-28     591
# ...          ...     ...
# 10834 2021-03-28     318
# 10835 2021-03-28     426
# 10836 2021-03-28     98
# 10837 2021-03-28     761
# 10838 2021-03-28     342
#
#                                                              app  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook
# 1      Pyaterochka
# 2      Refreshing app Free application that can use deal coupons
# 3      Citi Mobile®
# 4      Amex Mobile
# ...            ...
# 10834  FK Senica
# 10835  FK Jablonec
# 10836  FK Dedinje BGD
# 10837  FK Events
# 10838  iHoroscope - 2018 Daily Horoscope & Astrology
#
#              category  rating  reviews            app_size     installs  \
# 0      ART_AND_DESIGN  4.1     159      19M                 10,000+
# 1      FOOD_AND_DRINK  3.1     8412     Varies with device  1,000,000+
# 2      FOOD_AND_DRINK  3.5     10741    41M                 1,000,000+
# 3      FINANCE         4.0     78306    46M                 5,000,000+
# 4      FINANCE         4.3     24729    32M                 1,000,000+
# ...        ...         ...       ...    ...                        ...
# 10834  SPORTS         NaN      0        13M                 10+
# 10835  SPORTS         NaN      2        26M                 50+
# 10836  SPORTS          5.0     36       2.6M                100+
# 10837  PRODUCTIVITY   NaN      0        18M                 5+
# 10838  LIFESTYLE       4.5     398307   19M                 10,000,000+
#
#       app_type price content_rating        genres       last_updated  \
# 0      Free     0     Everyone       Art & Design  January 7, 2018
# 1      Free     0     Everyone       Food & Drink  July 19, 2018
# 2      Free     0     Everyone       Food & Drink  July 23, 2018
# 3      Free     0     Everyone       Finance       July 31, 2018
# 4      Free     0     Everyone       Finance       August 3, 2018
# ...     ...    ..          ...           ...                  ...
# 10834  Free     0     Everyone       Sports        August 24, 2017
# 10835  Free     0     Everyone       Sports        February 27, 2018
# 10836  Free     0     Everyone       Sports        February 11, 2017
# 10837  Free     0     Teen           Productivity  June 27, 2018
# 10838  Free     0     Everyone       Lifestyle     July 25, 2018
#
#           current_version     android_version  app_id  \
# 0      1.0.0               4.0.3 and up        7462
# 1      Varies with device  4.4 and up          7698
# 2      5.2.2               4.2 and up          7903
# 3      9.9.0               4.4 and up          3044
# 4      6.7.0               5.0 and up          1197
# ...      ...                      ...           ...
# 10834  14                  4.1 and up          4727
# 10835  1.0                 4.1 and up          4716
# 10836  1.1                 4.0 and up          4712
# 10837  7.17.2.1            5.0 and up          4714
# 10838  Varies with device  Varies with device  9986
#
#                             user_details
# 0      Sharon Young, 15, Washington
# 1      Marcus Barnes, 30, South Carolina
# 2      Rhonda Daniels, 58, Indiana
# 3      Michele Montoya, 17, Maine
# 4      Tracy Aguirre, 40, Nebraska
# ...                            ...
# 10834  Mrs. Misty Wilson, 55, New Mexico
# 10835  Adam Castro, 50, Oklahoma
# 10836  William Michael, 60, Hawaii
# 10837  Joyce Torres, 36, Florida
# 10838  Beth Edwards, 39, New Jersey
#
# [10839 rows x 17 columns]

# %%
#Check Total Duplicates
(users_app_data.duplicated().value_counts()/users_app_data.shape[0])*100
# Out:
# False    100.0
# dtype: float64

# %%
# Fill Nan in rating data
rating_data=users_app_data[pd.notnull(users_app_data['rating'])]
median=np.median(rating_data['rating'])
users_app_data['rating'].fillna(median,inplace=True)

users_app_data.dropna(inplace=True)

# %% [markdown]
# # Data Preprocessing

# %%
# converting last date
users_app_data['last_updated']=pd.to_datetime(users_app_data['last_updated'])
users_app_data['last_updated'] = users_app_data['last_updated'].dt.strftime('%Y-%m-%d')
users_app_data['last_updated'] = users_app_data['last_updated'].astype('datetime64[ns]')

# %%
# convert datatype to integer
users_app_data['rating'] = pd.to_numeric(users_app_data['rating'], errors='coerce')
users_app_data['reviews'] = pd.to_numeric(users_app_data['reviews'], errors='coerce')
users_app_data['installs'] = users_app_data['installs'].str.replace(',','').str.replace('+','').astype('int')
users_app_data['app_size'] = users_app_data['app_size'].str.replace('M','e+6').str.replace('k','e+3').str.replace('Varies with device','0').astype('float')
users_app_data['price'] = users_app_data['price'].str.replace('$','').astype('float')

# %%
users_app_data.dtypes
# Out:
# download_date      datetime64[ns]
# user_id            int64
# app                object
# category           object
# rating             float64
# reviews            int64
# app_size           float64
# installs           int64
# app_type           object
# price              float64
# content_rating     object
# genres             object
# last_updated       datetime64[ns]
# current_version    object
# android_version    object
# app_id             int64
# user_details       object
# dtype: object

# %%
users_app_data.index.names = ['event_id']
users_app_data.to_csv('users_app_data_streaming.csv')
# Out:
# Empty DataFrame
# Columns: [download_date, user_id, app, category, rating, reviews, app_size, installs, app_type, price, content_rating, genres, last_updated, current_version, android_version, app_id, user_details]
# Index: []
