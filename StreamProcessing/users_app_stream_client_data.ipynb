# %% [markdown]
# # Python Libraries

# %%
import pandas as pd
import os
import numpy as np
import pandas as pd
import datetime
import time
from datetime import datetime
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('max_colwidth', -1)
# Out:
# <style>.container { width:100% !important; }</style>
# <ipython-input-2-af59b17b2a7e>:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('max_colwidth', -1)

# %% [markdown]
# # Importing/Loading of Kaggle Google App Dataset

# %%
filepath = "/Users/ketansahu/Documents/DataEngineeringProject/GitHubRepo/googleplaystore.csv"
df = pd.read_csv(filepath ,encoding='utf-8')
col_name = ['app',  'category', 'rating', 'reviews', 'app_size', 'installs', 'app_type', 'price', 'content_rating', 'genres', 'last_updated', 'current_version', 'android_version']
df.columns = col_name

# %%
day =df.download_date.dt.day.values +  + df.download_date.dt.hour.values
day
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-41-983f63f1851f> in <module>
# ----> 1 day =df.download_date.dt.day.values + '_' + df.download_date.dt.hour.values
#       2 day
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U21'), dtype('<U21')) -> dtype('<U21')

# %%
#Add 1000 Random user_id
df["user_id"] = np.random.randint(1, 1000, len(df))
#Add download date of today
#df["download_date"] = np.random.choice(pd.date_range('2020-01-01', '2021-01-01'), len(df))
df["download_date"] = pd.date_range('today', periods=len(df), freq='1S')
df['download_date'] = df['download_date'].map(lambda x: x.strftime('%Y-%m-%d %H:%M:%S'))
df['download_date'] = df['download_date'].astype('datetime64[ns]')
#hours = df.download_date.dt.hour.values
#df['timeOfDay'] = np.where(hours <= 12)
#df['timeOfDay'] = df.groupby(['download_date']).ngroup()
#reindex the column order
df = df.reindex(columns=['timeOfDay','download_date', 'user_id', 'app',  'category', 'rating', 'reviews', 'app_size', 'installs', 'app_type', 'price', 'content_rating', 'genres', 'last_updated', 'current_version', 'android_version'])
#Sort the Dataframe based on the the download_date
df = df.sort_values('download_date')
#reset the index=row numbers
df = df.reset_index(drop =True)
df.dtypes
# Out:
# timeOfDay          object
# download_date      datetime64[ns]
# user_id            int64
# app                object
# category           object
# rating             float64
# reviews            int64
# app_size           object
# installs           object
# app_type           object
# price              object
# content_rating     object
# genres             object
# last_updated       object
# current_version    object
# android_version    object
# dtype: object

# %%
df
# Out:
#         timeOfDay       download_date  user_id  \
# 0      2021-04-29 2021-04-29 21:18:56  860
# 1      2021-04-29 2021-04-29 21:18:57  551
# 2      2021-04-29 2021-04-29 21:18:58  384
# 3      2021-04-29 2021-04-29 21:18:59  129
# 4      2021-04-29 2021-04-29 21:19:00  172
# ...           ...                 ...  ...
# 10834  2021-04-30 2021-04-30 00:19:30  748
# 10835  2021-04-30 2021-04-30 00:19:31  378
# 10836  2021-04-30 2021-04-30 00:19:32  247
# 10837  2021-04-30 2021-04-30 00:19:33  543
# 10838  2021-04-30 2021-04-30 00:19:34  708
#
#                                                       app  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook
# 1      Coloring book moana
# 2      U Launcher Lite – FREE Live Cool Themes, Hide Apps
# 3      Sketch - Draw & Paint
# 4      Pixel Draw - Number Art Coloring Book
# ...                                      ...
# 10834  Sya9a Maroc - FR
# 10835  Fr. Mike Schmitz Audio Teachings
# 10836  Parkinson Exercices FR
# 10837  The SCP Foundation DB fr nn5n
# 10838  iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   category  rating  reviews            app_size     installs  \
# 0      ART_AND_DESIGN       4.1     159      19M                 10,000+
# 1      ART_AND_DESIGN       3.9     967      14M                 500,000+
# 2      ART_AND_DESIGN       4.7     87510    8.7M                5,000,000+
# 3      ART_AND_DESIGN       4.5     215644   25M                 50,000,000+
# 4      ART_AND_DESIGN       4.3     967      2.8M                100,000+
# ...               ...       ...     ...       ...                     ...
# 10834  FAMILY               4.5     38       53M                 5,000+
# 10835  FAMILY               5.0     4        3.6M                100+
# 10836  MEDICAL             NaN      3        9.5M                1,000+
# 10837  BOOKS_AND_REFERENCE  4.5     114      Varies with device  1,000+
# 10838  LIFESTYLE            4.5     398307   19M                 10,000,000+
#
#       app_type price content_rating                     genres  \
# 0      Free     0     Everyone       Art & Design
# 1      Free     0     Everyone       Art & Design;Pretend Play
# 2      Free     0     Everyone       Art & Design
# 3      Free     0     Teen           Art & Design
# 4      Free     0     Everyone       Art & Design;Creativity
# ...     ...    ..          ...                           ...
# 10834  Free     0     Everyone       Education
# 10835  Free     0     Everyone       Education
# 10836  Free     0     Everyone       Medical
# 10837  Free     0     Mature 17+     Books & Reference
# 10838  Free     0     Everyone       Lifestyle
#
#            last_updated     current_version     android_version
# 0      January 7, 2018   1.0.0               4.0.3 and up
# 1      January 15, 2018  2.0.0               4.0.3 and up
# 2      August 1, 2018    1.2.4               4.0.3 and up
# 3      June 8, 2018      Varies with device  4.2 and up
# 4      June 20, 2018     1.1                 4.4 and up
# ...              ...     ...                        ...
# 10834  July 25, 2017     1.48                4.1 and up
# 10835  July 6, 2018      1.0                 4.1 and up
# 10836  January 20, 2017  1.0                 2.2 and up
# 10837  January 19, 2015  Varies with device  Varies with device
# 10838  July 25, 2018     Varies with device  Varies with device
#
# [10839 rows x 16 columns]

# %%
df['timeOfDay']

# %% [markdown]
# # App Details

# %%
#Assign app_id to each unique app in the dataset
df['app_id'] = df.groupby(['app']).ngroup()
df['app_id'] = df['app_id'].map(lambda q: q+500)

# %%
#Total unique app in the data set
df_app = df['app'].unique()
len(df_app)
# Out:
# 9659

# %% [markdown]
# # Fake User Details Dataset

# %%
from faker import Faker
fake = Faker()
n = 1000
faker_data = pd.DataFrame([[fake.name(), np.random.randint(14,65), fake.state()] for _ in range(n)],
     columns=['user_name', 'user_age', 'user_location'])
user_id = pd.factorize(faker_data.apply(tuple, axis=1))[0] + 1
faker_data.insert(loc=0, column='user_id', value=user_id)
faker_data.head(30)
# Out:
#     user_id           user_name  user_age  user_location
# 0   1        Michael Huerta      14        Hawaii
# 1   2        Sherri Green        59        Florida
# 2   3        Anthony Madden      14        Massachusetts
# 3   4        Leslie Butler       50        New Mexico
# 4   5        Cynthia King        46        New York
# 5   6        Ashley Meyer        48        Georgia
# 6   7        Lisa Anderson       41        Virginia
# 7   8        Amber Potts         23        Alabama
# 8   9        Kristine Williams   36        Pennsylvania
# 9   10       Adam Cross          30        New Hampshire
# 10  11       Taylor Ruiz         51        Delaware
# 11  12       Leslie Holt         30        Michigan
# 12  13       Jessica Morales     29        Oregon
# 13  14       Christine Crosby    24        Washington
# 14  15       Heather Stewart     19        Arkansas
# 15  16       Douglas Woods       24        Utah
# 16  17       Richard Woods       57        New Hampshire
# 17  18       Joanna Lynch        60        Rhode Island
# 18  19       Amanda Rivera       43        Virginia
# 19  20       Alejandro Peterson  47        California
# 20  21       Ana Shaw            33        New York
# 21  22       Danielle Gomez      22        Vermont
# 22  23       Joseph Leblanc      55        Montana
# 23  24       Yvette Lambert      22        Virginia
# 24  25       Sabrina Day         27        Delaware
# 25  26       Thomas Scott        22        West Virginia
# 26  27       Martin Morgan       21        Minnesota
# 27  28       Rebecca Rice        27        Washington
# 28  29       Linda Roberts       64        Nebraska
# 29  30       Mark Pham           60        New Jersey

# %% [markdown]
# # Data Merge (Kaggle Google App Data + Fake User Details Data)

# %%
#Merge Faker data to kaggle data on left
users_app_data = df.merge(faker_data, on='user_id', how='left')
users_app_data
# Out:
#              download_date  user_id  \
# 0      2021-04-27 21:58:57  655
# 1      2021-04-27 21:58:58  474
# 2      2021-04-27 21:58:59  841
# 3      2021-04-27 21:59:00  38
# 4      2021-04-27 21:59:01  442
# ...                    ...  ...
# 10834  2021-04-28 00:59:31  122
# 10835  2021-04-28 00:59:32  888
# 10836  2021-04-28 00:59:33  299
# 10837  2021-04-28 00:59:34  396
# 10838  2021-04-28 00:59:35  313
#
#                                                       app  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook
# 1      Coloring book moana
# 2      U Launcher Lite – FREE Live Cool Themes, Hide Apps
# 3      Sketch - Draw & Paint
# 4      Pixel Draw - Number Art Coloring Book
# ...                                      ...
# 10834  Sya9a Maroc - FR
# 10835  Fr. Mike Schmitz Audio Teachings
# 10836  Parkinson Exercices FR
# 10837  The SCP Foundation DB fr nn5n
# 10838  iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   category  rating  reviews            app_size     installs  \
# 0      ART_AND_DESIGN       4.1     159      19M                 10,000+
# 1      ART_AND_DESIGN       3.9     967      14M                 500,000+
# 2      ART_AND_DESIGN       4.7     87510    8.7M                5,000,000+
# 3      ART_AND_DESIGN       4.5     215644   25M                 50,000,000+
# 4      ART_AND_DESIGN       4.3     967      2.8M                100,000+
# ...               ...       ...     ...       ...                     ...
# 10834  FAMILY               4.5     38       53M                 5,000+
# 10835  FAMILY               5.0     4        3.6M                100+
# 10836  MEDICAL             NaN      3        9.5M                1,000+
# 10837  BOOKS_AND_REFERENCE  4.5     114      Varies with device  1,000+
# 10838  LIFESTYLE            4.5     398307   19M                 10,000,000+
#
#       app_type price content_rating                     genres  \
# 0      Free     0     Everyone       Art & Design
# 1      Free     0     Everyone       Art & Design;Pretend Play
# 2      Free     0     Everyone       Art & Design
# 3      Free     0     Teen           Art & Design
# 4      Free     0     Everyone       Art & Design;Creativity
# ...     ...    ..          ...                           ...
# 10834  Free     0     Everyone       Education
# 10835  Free     0     Everyone       Education
# 10836  Free     0     Everyone       Medical
# 10837  Free     0     Mature 17+     Books & Reference
# 10838  Free     0     Everyone       Lifestyle
#
#            last_updated     current_version     android_version  app_id  \
# 0      January 7, 2018   1.0.0               4.0.3 and up        7462
# 1      January 15, 2018  2.0.0               4.0.3 and up        3132
# 2      August 1, 2018    1.2.4               4.0.3 and up        9156
# 3      June 8, 2018      Varies with device  4.2 and up          8327
# 4      June 20, 2018     1.1                 4.4 and up          7522
# ...              ...     ...                        ...           ...
# 10834  July 25, 2017     1.48                4.1 and up          8673
# 10835  July 6, 2018      1.0                 4.1 and up          5109
# 10836  January 20, 2017  1.0                 2.2 and up          7391
# 10837  January 19, 2015  Varies with device  Varies with device  8894
# 10838  July 25, 2018     Varies with device  Varies with device  9986
#
#               user_name  user_age   user_location
# 0      Karen Bowman      34        Maryland
# 1      Kyle Schneider    30        Colorado
# 2      Deborah Matthews  64        Missouri
# 3      Abigail Burgess   61        North Carolina
# 4      Shawna Baker      62        Connecticut
# ...             ...      ..                ...
# 10834  Kristin Wright    22        Ohio
# 10835  Julia Gonzalez    14        Vermont
# 10836  Joseph Walls      62        Pennsylvania
# 10837  Ebony Russell     33        Massachusetts
# 10838  Judy Pham         26        Mississippi
#
# [10839 rows x 19 columns]

# %%
#Check Total Duplicates
(users_app_data.duplicated().value_counts()/users_app_data.shape[0])*100
# Out:
# False    100.0
# dtype: float64

# %%
# Fill Nan in rating data
rating_data=users_app_data[pd.notnull(users_app_data['rating'])]
median=np.median(rating_data['rating'])
users_app_data['rating'].fillna(median,inplace=True)

# %%
#Drop Nan from dataset
users_app_data.dropna(inplace=True)

# %% [markdown]
# # Data Preprocessing

# %%
# converting last date
users_app_data['last_updated'] = pd.to_datetime(users_app_data['last_updated'])
users_app_data['last_updated'] = users_app_data['last_updated'].dt.strftime('%Y-%m-%d')
users_app_data['last_updated'] = users_app_data['last_updated'].astype('datetime64[ns]')

# %%
# convert datatype to integer
users_app_data['rating'] = pd.to_numeric(users_app_data['rating'], errors='coerce')
users_app_data['reviews'] = pd.to_numeric(users_app_data['reviews'], errors='coerce')
users_app_data['installs'] = users_app_data['installs'].str.replace(',','').str.replace('+','').astype('int')
users_app_data['app_size'] = users_app_data['app_size'].str.replace('M','e+6').str.replace('k','e+3').str.replace('Varies with device','0').astype('float')
users_app_data['price'] = users_app_data['price'].str.replace('$','').astype('float')

# %%
users_app_data.dtypes
# Out:
# download_date              object
# user_id                     int64
# app                        object
# category                   object
# rating                    float64
# reviews                     int64
# app_size                  float64
# installs                    int64
# app_type                   object
# price                     float64
# content_rating             object
# genres                     object
# last_updated       datetime64[ns]
# current_version            object
# android_version            object
# app_id                      int64
# user_name                  object
# user_age                    int64
# user_location              object
# dtype: object

# %%
users_app_data.index.names = ['event_id']
users_app_data = users_app_data[0:8]
users_app_data.to_csv('users_app_data_stream_temp.csv')
