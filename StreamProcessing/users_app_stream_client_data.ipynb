# %% [markdown]
# # Python Libraries

# %%
import pandas as pd
import os
import numpy as np
import pandas as pd
import datetime
import time
from datetime import datetime
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('max_colwidth', -1)
# Out:
# <style>.container { width:100% !important; }</style>
# <ipython-input-14-af59b17b2a7e>:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('max_colwidth', -1)

# %% [markdown]
# # Importing/Loading of Kaggle Google App Dataset

# %%
filepath = "/Users/ketansahu/Documents/DataEngineeringProject/GitHubRepo/googleplaystore.csv"
df = pd.read_csv(filepath ,encoding='utf-8')
col_name = ['app',  'category', 'rating', 'reviews', 'app_size', 'installs', 'app_type', 'price', 'content_rating', 'genres', 'last_updated', 'current_version', 'android_version']
df.columns = col_name

# %%
#Add 1000 Random user_id
df["user_id"] = np.random.randint(1, 1000, len(df))
#Add download date of today
#df["download_date"] = np.random.choice(pd.date_range('2020-01-01', '2021-01-01'), len(df))
df["download_date"] = pd.date_range('today', periods=len(df), freq='100L')
df['download_date'] = df['download_date'].map(lambda x: x.strftime('%Y-%m-%d %H:%M:%S'))
df['download_date'] = df['download_date'].astype('datetime64[ns]')
#hours = df.download_date.dt.hour.values
#df['timeOfDay'] = np.where(hours <= 12)
#df['timeOfDay'] = df.groupby(['download_date']).ngroup()
#reindex the column order
df = df.reindex(columns=['download_date', 'user_id', 'app',  'category', 'rating', 'reviews', 'app_size', 'installs', 'app_type', 'price', 'content_rating', 'genres', 'last_updated', 'current_version', 'android_version'])
#Sort the Dataframe based on the the download_date
df = df.sort_values('download_date')
#reset the index=row numbers
df = df.reset_index(drop =True)
df.dtypes
# Out:
# download_date      datetime64[ns]
# user_id            int64
# app                object
# category           object
# rating             float64
# reviews            int64
# app_size           object
# installs           object
# app_type           object
# price              object
# content_rating     object
# genres             object
# last_updated       object
# current_version    object
# android_version    object
# dtype: object

# %%
df.head(30)
# Out:
#          download_date  user_id  \
# 0  2021-05-05 18:09:17  762
# 1  2021-05-05 18:09:17  623
# 2  2021-05-05 18:09:17  290
# 3  2021-05-05 18:09:17  786
# 4  2021-05-05 18:09:17  25
# 5  2021-05-05 18:09:17  31
# 6  2021-05-05 18:09:17  434
# 7  2021-05-05 18:09:18  109
# 8  2021-05-05 18:09:18  535
# 9  2021-05-05 18:09:18  241
# 10 2021-05-05 18:09:18  470
# 11 2021-05-05 18:09:18  502
# 12 2021-05-05 18:09:18  110
# 13 2021-05-05 18:09:18  391
# 14 2021-05-05 18:09:18  440
# 15 2021-05-05 18:09:18  291
# 16 2021-05-05 18:09:18  865
# 17 2021-05-05 18:09:19  419
# 18 2021-05-05 18:09:19  102
# 19 2021-05-05 18:09:19  610
# 20 2021-05-05 18:09:19  485
# 21 2021-05-05 18:09:19  681
# 22 2021-05-05 18:09:19  855
# 23 2021-05-05 18:09:19  422
# 24 2021-05-05 18:09:19  170
# 25 2021-05-05 18:09:19  232
# 26 2021-05-05 18:09:19  597
# 27 2021-05-05 18:09:20  11
# 28 2021-05-05 18:09:20  691
# 29 2021-05-05 18:09:20  705
#
#                                                    app        category  \
# 0   Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN
# 1   Coloring book moana                                 ART_AND_DESIGN
# 2   U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN
# 3   Sketch - Draw & Paint                               ART_AND_DESIGN
# 4   Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN
# 5   Paper flowers instructions                          ART_AND_DESIGN
# 6   Smoke Effect Photo Maker - Smoke Editor             ART_AND_DESIGN
# 7   Photo Designer - Write your name with shapes        ART_AND_DESIGN
# 8   Learn To Draw Kawaii Characters                     ART_AND_DESIGN
# 9   3D Color Pixel by Number - Sandbox Art Coloring     ART_AND_DESIGN
# 10  Mandala Coloring Book                               ART_AND_DESIGN
# 11  Tattoo Name On My Photo Editor                      ART_AND_DESIGN
# 12  Text on Photo - Fonteee                             ART_AND_DESIGN
# 13  Kids Paint Free - Drawing Fun                       ART_AND_DESIGN
# 14  Garden Coloring Book                                ART_AND_DESIGN
# 15  Infinite Painter                                    ART_AND_DESIGN
# 16  Name Art Photo Editor - Focus n Filters             ART_AND_DESIGN
# 17  Mcqueen Coloring pages                              ART_AND_DESIGN
# 18  Colorfit - Drawing & Coloring                       ART_AND_DESIGN
# 19  Harley Quinn wallpapers HD                          ART_AND_DESIGN
# 20  HD Mickey Minnie Wallpapers                         ART_AND_DESIGN
# 21  Superheroes Wallpapers | 4K Backgrounds             ART_AND_DESIGN
# 22  Logo Maker - Small Business                         ART_AND_DESIGN
# 23  ibis Paint X                                        ART_AND_DESIGN
# 24  FlipaClip - Cartoon animation                       ART_AND_DESIGN
# 25  350 Diy Room Decor Ideas                            ART_AND_DESIGN
# 26  Boys Photo Editor - Six Pack & Men's Suit           ART_AND_DESIGN
# 27  Anime Manga Coloring Book                           ART_AND_DESIGN
# 28  Animated Photo Editor                               ART_AND_DESIGN
# 29  Pencil Sketch Drawing                               ART_AND_DESIGN
#
#     rating  reviews app_size     installs app_type price content_rating  \
# 0   4.1     159      19M      10,000+      Free     0     Everyone
# 1   3.9     967      14M      500,000+     Free     0     Everyone
# 2   4.7     87510    8.7M     5,000,000+   Free     0     Everyone
# 3   4.5     215644   25M      50,000,000+  Free     0     Teen
# 4   4.3     967      2.8M     100,000+     Free     0     Everyone
# 5   4.4     167      5.6M     50,000+      Free     0     Everyone
# 6   3.8     178      19M      50,000+      Free     0     Everyone
# 7   4.7     3632     5.5M     500,000+     Free     0     Everyone
# 8   3.2     55       2.7M     5,000+       Free     0     Everyone
# 9   4.4     1518     37M      100,000+     Free     0     Everyone
# 10  4.6     4326     21M      100,000+     Free     0     Everyone
# 11  4.2     44829    20M      10,000,000+  Free     0     Teen
# 12  4.4     13880    28M      1,000,000+   Free     0     Everyone
# 13  4.7     121      3.1M     10,000+      Free     0     Everyone
# 14  4.4     13791    33M      1,000,000+   Free     0     Everyone
# 15  4.1     36815    29M      1,000,000+   Free     0     Everyone
# 16  4.4     8788     12M      1,000,000+   Free     0     Everyone
# 17 NaN      61       7.0M     100,000+     Free     0     Everyone
# 18  4.7     20260    25M      500,000+     Free     0     Everyone
# 19  4.8     192      6.0M     10,000+      Free     0     Everyone
# 20  4.7     118      23M      50,000+      Free     0     Everyone
# 21  4.7     7699     4.2M     500,000+     Free     0     Everyone 10+
# 22  4.0     450      14M      100,000+     Free     0     Everyone
# 23  4.6     224399   31M      10,000,000+  Free     0     Everyone
# 24  4.3     194216   39M      5,000,000+   Free     0     Everyone
# 25  4.5     27       17M      10,000+      Free     0     Everyone
# 26  4.1     654      12M      100,000+     Free     0     Everyone
# 27  4.5     5035     11M      100,000+     Free     0     Everyone
# 28  4.1     203      6.1M     100,000+     Free     0     Everyone
# 29  3.9     136      4.6M     10,000+      Free     0     Everyone
#
#                              genres        last_updated     current_version  \
# 0   Art & Design                     January 7, 2018     1.0.0
# 1   Art & Design;Pretend Play        January 15, 2018    2.0.0
# 2   Art & Design                     August 1, 2018      1.2.4
# 3   Art & Design                     June 8, 2018        Varies with device
# 4   Art & Design;Creativity          June 20, 2018       1.1
# 5   Art & Design                     March 26, 2017      1.0
# 6   Art & Design                     April 26, 2018      1.1
# 7   Art & Design                     July 31, 2018       3.1
# 8   Art & Design                     June 6, 2018        NaN
# 9   Art & Design                     August 3, 2018      1.2.3
# 10  Art & Design                     June 26, 2018       1.0.4
# 11  Art & Design                     April 2, 2018       3.8
# 12  Art & Design                     October 27, 2017    1.0.4
# 13  Art & Design;Creativity          July 3, 2018        2.8
# 14  Art & Design                     September 20, 2017  2.9.2
# 15  Art & Design                     June 14, 2018       6.1.61.1
# 16  Art & Design                     July 31, 2018       1.0.15
# 17  Art & Design;Action & Adventure  March 7, 2018       1.0.0
# 18  Art & Design;Creativity          October 11, 2017    1.0.8
# 19  Art & Design                     April 25, 2018      1.5
# 20  Art & Design                     July 7, 2018        1.1.3
# 21  Art & Design                     July 12, 2018       2.2.6.2
# 22  Art & Design                     April 20, 2018      4.0
# 23  Art & Design                     July 30, 2018       5.5.4
# 24  Art & Design                     August 3, 2018      2.2.5
# 25  Art & Design                     November 7, 2017    1.0
# 26  Art & Design                     March 20, 2018      1.1
# 27  Art & Design                     July 19, 2018       2.20
# 28  Art & Design                     March 21, 2018      1.03
# 29  Art & Design                     July 12, 2018       6.0
#
#    android_version
# 0   4.0.3 and up
# 1   4.0.3 and up
# 2   4.0.3 and up
# 3   4.2 and up
# 4   4.4 and up
# 5   2.3 and up
# 6   4.0.3 and up
# 7   4.1 and up
# 8   4.2 and up
# 9   2.3 and up
# 10  4.4 and up
# 11  4.1 and up
# 12  4.1 and up
# 13  4.0.3 and up
# 14  3.0 and up
# 15  4.2 and up
# 16  4.0 and up
# 17  4.1 and up
# 18  4.0.3 and up
# 19  3.0 and up
# 20  4.1 and up
# 21  4.0.3 and up
# 22  4.1 and up
# 23  4.1 and up
# 24  4.0.3 and up
# 25  2.3 and up
# 26  4.0.3 and up
# 27  4.0 and up
# 28  4.0.3 and up
# 29  2.3 and up

# %% [markdown]
# # App Details

# %%
#Assign app_id to each unique app in the dataset
df['app_id'] = df.groupby(['app']).ngroup()
df['app_id'] = df['app_id'].map(lambda q: q+500)

# %%
#Total unique app in the data set
df_app = df['app'].unique()
len(df_app)
# Out:
# 9659

# %% [markdown]
# # Fake User Details Dataset

# %%
from faker import Faker
fake = Faker()
n = 1000
faker_data = pd.DataFrame([[fake.name(), np.random.randint(14,65), fake.state()] for _ in range(n)],
     columns=['user_name', 'user_age', 'user_location'])
user_id = pd.factorize(faker_data.apply(tuple, axis=1))[0] + 1
faker_data.insert(loc=0, column='user_id', value=user_id)
faker_data.head(30)
# Out:
#     user_id           user_name  user_age  user_location
# 0   1        Barbara Bates       64        Montana
# 1   2        Sharon Brown        20        California
# 2   3        Rebecca Pollard     43        Oklahoma
# 3   4        Jared Bell          23        Colorado
# 4   5        John Mcbride        48        New Mexico
# 5   6        Michelle Murphy     54        Texas
# 6   7        Robert Collins      36        New Mexico
# 7   8        Jennifer Miller     15        Alabama
# 8   9        Donald Harrell      15        Iowa
# 9   10       Adam Strickland     27        New York
# 10  11       Paul Young          55        Massachusetts
# 11  12       Laura Willis        41        Indiana
# 12  13       Brenda Sawyer       52        California
# 13  14       Emily Hunter        25        Nevada
# 14  15       Erin Bell MD        63        Massachusetts
# 15  16       Alan Cox            20        Oregon
# 16  17       Karina Le           41        Alaska
# 17  18       David Moore         58        Alabama
# 18  19       Timothy Pena        47        West Virginia
# 19  20       Christine Johnson   43        Rhode Island
# 20  21       Debra Williams      39        New Hampshire
# 21  22       Cynthia Brown       61        Idaho
# 22  23       Paul Mata           41        Louisiana
# 23  24       Brian Gardner       30        Arizona
# 24  25       Dr. Kathleen Chung  32        New Mexico
# 25  26       Michael Hubbard     55        West Virginia
# 26  27       Dana Graham         26        Ohio
# 27  28       Jennifer Howard     32        Michigan
# 28  29       Alexander Brown     57        Michigan
# 29  30       Paul Santiago       31        Mississippi

# %% [markdown]
# # Data Merge (Kaggle Google App Data + Fake User Details Data)

# %%
#Merge Faker data to kaggle data on left
users_app_data = df.merge(faker_data, on='user_id', how='left')
users_app_data
# Out:
#             download_date  user_id  \
# 0     2021-05-05 18:09:17  762
# 1     2021-05-05 18:09:17  623
# 2     2021-05-05 18:09:17  290
# 3     2021-05-05 18:09:17  786
# 4     2021-05-05 18:09:17  25
# ...                   ...  ..
# 10834 2021-05-05 18:27:20  293
# 10835 2021-05-05 18:27:20  379
# 10836 2021-05-05 18:27:20  698
# 10837 2021-05-05 18:27:21  794
# 10838 2021-05-05 18:27:21  599
#
#                                                       app  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook
# 1      Coloring book moana
# 2      U Launcher Lite – FREE Live Cool Themes, Hide Apps
# 3      Sketch - Draw & Paint
# 4      Pixel Draw - Number Art Coloring Book
# ...                                      ...
# 10834  News Minecraft.fr
# 10835  Bulgarian French Dictionary Fr
# 10836  Chemin (fr)
# 10837  The SCP Foundation DB fr nn5n
# 10838  iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   category  rating  reviews            app_size     installs  \
# 0      ART_AND_DESIGN       4.1     159      19M                 10,000+
# 1      ART_AND_DESIGN       3.9     967      14M                 500,000+
# 2      ART_AND_DESIGN       4.7     87510    8.7M                5,000,000+
# 3      ART_AND_DESIGN       4.5     215644   25M                 50,000,000+
# 4      ART_AND_DESIGN       4.3     967      2.8M                100,000+
# ...               ...       ...     ...       ...                     ...
# 10834  NEWS_AND_MAGAZINES   3.8     881      2.3M                100,000+
# 10835  BOOKS_AND_REFERENCE  4.6     603      7.4M                10,000+
# 10836  BOOKS_AND_REFERENCE  4.8     44       619k                1,000+
# 10837  BOOKS_AND_REFERENCE  4.5     114      Varies with device  1,000+
# 10838  LIFESTYLE            4.5     398307   19M                 10,000,000+
#
#       app_type price content_rating                     genres  \
# 0      Free     0     Everyone       Art & Design
# 1      Free     0     Everyone       Art & Design;Pretend Play
# 2      Free     0     Everyone       Art & Design
# 3      Free     0     Teen           Art & Design
# 4      Free     0     Everyone       Art & Design;Creativity
# ...     ...    ..          ...                           ...
# 10834  Free     0     Everyone       News & Magazines
# 10835  Free     0     Everyone       Books & Reference
# 10836  Free     0     Everyone       Books & Reference
# 10837  Free     0     Mature 17+     Books & Reference
# 10838  Free     0     Everyone       Lifestyle
#
#            last_updated     current_version     android_version  app_id  \
# 0      January 7, 2018   1.0.0               4.0.3 and up        7462
# 1      January 15, 2018  2.0.0               4.0.3 and up        3132
# 2      August 1, 2018    1.2.4               4.0.3 and up        9156
# 3      June 8, 2018      Varies with device  4.2 and up          8327
# 4      June 20, 2018     1.1                 4.4 and up          7522
# ...              ...     ...                        ...           ...
# 10834  January 20, 2014  1.5                 1.6 and up          7078
# 10835  June 19, 2016     2.96                4.1 and up          2315
# 10836  March 23, 2014    0.8                 2.2 and up          2993
# 10837  January 19, 2015  Varies with device  Varies with device  8894
# 10838  July 25, 2018     Varies with device  Varies with device  9986
#
#                 user_name  user_age  user_location
# 0      Louis Smith         18        North Dakota
# 1      Tracey Rhodes       58        Florida
# 2      Scott Smith         21        Nebraska
# 3      Tamara Oconnell     33        New Hampshire
# 4      Dr. Kathleen Chung  32        New Mexico
# ...                   ...  ..               ...
# 10834  Sandra Miller       59        Montana
# 10835  Ashley Miller       56        Mississippi
# 10836  Mrs. Debra Newton   16        Massachusetts
# 10837  Gregory Medina      60        New Mexico
# 10838  Heidi Evans         24        Tennessee
#
# [10839 rows x 19 columns]

# %%
#Check Total Duplicates
(users_app_data.duplicated().value_counts()/users_app_data.shape[0])*100
# Out:
# False    100.0
# dtype: float64

# %%
# Fill Nan in rating data
rating_data=users_app_data[pd.notnull(users_app_data['rating'])]
median=np.median(rating_data['rating'])
users_app_data['rating'].fillna(median,inplace=True)

# %%
#Drop Nan from dataset
users_app_data.dropna(inplace=True)

# %% [markdown]
# # Data Preprocessing

# %%
# converting last date
users_app_data['last_updated'] = pd.to_datetime(users_app_data['last_updated'])
users_app_data['last_updated'] = users_app_data['last_updated'].dt.strftime('%Y-%m-%d')
users_app_data['last_updated'] = users_app_data['last_updated'].astype('datetime64[ns]')

# %%
# convert datatype to integer
users_app_data['rating'] = pd.to_numeric(users_app_data['rating'], errors='coerce')
users_app_data['reviews'] = pd.to_numeric(users_app_data['reviews'], errors='coerce')
users_app_data['installs'] = users_app_data['installs'].str.replace(',','').str.replace('+','').astype('int')
users_app_data['app_size'] = users_app_data['app_size'].str.replace('M','e+6').str.replace('k','e+3').str.replace('Varies with device','0').astype('float')
users_app_data['price'] = users_app_data['price'].str.replace('$','').astype('float')

# %%
users_app_data.dtypes
# Out:
# download_date              object
# user_id                     int64
# app                        object
# category                   object
# rating                    float64
# reviews                     int64
# app_size                  float64
# installs                    int64
# app_type                   object
# price                     float64
# content_rating             object
# genres                     object
# last_updated       datetime64[ns]
# current_version            object
# android_version            object
# app_id                      int64
# user_name                  object
# user_age                    int64
# user_location              object
# dtype: object

# %%
users_app_data.index.names = ['event_id']
#users_app_data = users_app_data[0:8]
users_app_data.to_csv('users_app_data_stream_temp1.csv')
