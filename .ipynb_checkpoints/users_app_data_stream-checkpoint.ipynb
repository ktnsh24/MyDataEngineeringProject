# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('max_colwidth', -1)
# Out:
# <style>.container { width:100% !important; }</style>
# <ipython-input-76-af59b17b2a7e>:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('max_colwidth', -1)

# %% [markdown]
# # Python Libraries

# %%
import pandas as pd
import os
import numpy as np
import pandas as pd
import datetime
import time
from datetime import datetime
import matplotlib.pyplot as plt
from collections import defaultdict

# %% [markdown]
# # Importing/Loading of Kaggle Google App Dataset

# %%
filepath = "/Users/ketansahu/Documents/DataEngineeringProject/GitHubRepo/googleplaystore.csv"
df = pd.read_csv(filepath ,encoding='utf-8')
col_name = ['app',  'category', 'rating', 'reviews', 'app_size', 'installs', 'app_type', 'price', 'content_rating', 'genres', 'last_updated', 'current_version', 'android_version']
df.columns = col_name

# %%
#Add 1000 Random user_id
df["user_id"] = np.random.randint(1, 1000, len(df))
#Add download date of today
#df["download_date"] = np.random.choice(pd.date_range('2020-01-01', '2021-01-01'), len(df))
df["download_date"] = pd.date_range('today', periods=len(df), freq='1S')
df['download_date'] = df['download_date'].map(lambda x: x.strftime('%Y-%m-%d %H:%M:%S'))
#reindex the column order
df = df.reindex(columns=['download_date', 'user_id', 'app',  'category', 'rating', 'reviews', 'app_size', 'installs', 'app_type', 'price', 'content_rating', 'genres', 'last_updated', 'current_version', 'android_version'])
#Sort the Dataframe based on the the download_date
df = df.sort_values('download_date')
#reset the index=row numbers
df = df.reset_index(drop =True)
df
# Out:
#              download_date  user_id  \
# 0      2021-03-28 15:01:57  82
# 1      2021-03-28 15:01:58  698
# 2      2021-03-28 15:01:59  47
# 3      2021-03-28 15:02:00  800
# 4      2021-03-28 15:02:01  775
# ...                    ...  ...
# 10834  2021-03-28 18:02:31  738
# 10835  2021-03-28 18:02:32  385
# 10836  2021-03-28 18:02:33  55
# 10837  2021-03-28 18:02:34  467
# 10838  2021-03-28 18:02:35  320
#
#                                                       app  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook
# 1      Coloring book moana
# 2      U Launcher Lite – FREE Live Cool Themes, Hide Apps
# 3      Sketch - Draw & Paint
# 4      Pixel Draw - Number Art Coloring Book
# ...                                      ...
# 10834  Sya9a Maroc - FR
# 10835  Fr. Mike Schmitz Audio Teachings
# 10836  Parkinson Exercices FR
# 10837  The SCP Foundation DB fr nn5n
# 10838  iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   category  rating  reviews            app_size     installs  \
# 0      ART_AND_DESIGN       4.1     159      19M                 10,000+
# 1      ART_AND_DESIGN       3.9     967      14M                 500,000+
# 2      ART_AND_DESIGN       4.7     87510    8.7M                5,000,000+
# 3      ART_AND_DESIGN       4.5     215644   25M                 50,000,000+
# 4      ART_AND_DESIGN       4.3     967      2.8M                100,000+
# ...               ...       ...     ...       ...                     ...
# 10834  FAMILY               4.5     38       53M                 5,000+
# 10835  FAMILY               5.0     4        3.6M                100+
# 10836  MEDICAL             NaN      3        9.5M                1,000+
# 10837  BOOKS_AND_REFERENCE  4.5     114      Varies with device  1,000+
# 10838  LIFESTYLE            4.5     398307   19M                 10,000,000+
#
#       app_type price content_rating                     genres  \
# 0      Free     0     Everyone       Art & Design
# 1      Free     0     Everyone       Art & Design;Pretend Play
# 2      Free     0     Everyone       Art & Design
# 3      Free     0     Teen           Art & Design
# 4      Free     0     Everyone       Art & Design;Creativity
# ...     ...    ..          ...                           ...
# 10834  Free     0     Everyone       Education
# 10835  Free     0     Everyone       Education
# 10836  Free     0     Everyone       Medical
# 10837  Free     0     Mature 17+     Books & Reference
# 10838  Free     0     Everyone       Lifestyle
#
#            last_updated     current_version     android_version
# 0      January 7, 2018   1.0.0               4.0.3 and up
# 1      January 15, 2018  2.0.0               4.0.3 and up
# 2      August 1, 2018    1.2.4               4.0.3 and up
# 3      June 8, 2018      Varies with device  4.2 and up
# 4      June 20, 2018     1.1                 4.4 and up
# ...              ...     ...                        ...
# 10834  July 25, 2017     1.48                4.1 and up
# 10835  July 6, 2018      1.0                 4.1 and up
# 10836  January 20, 2017  1.0                 2.2 and up
# 10837  January 19, 2015  Varies with device  Varies with device
# 10838  July 25, 2018     Varies with device  Varies with device
#
# [10839 rows x 15 columns]

# %% [markdown]
# # App Details

# %%
#Assign app_id to each unique app in the dataset
df['app_id'] = df.groupby(['app']).ngroup()
df['app_id'] = df['app_id'].map(lambda q: q+500)

# %%
#Total unique app in the data set
df_app = df['app'].unique()
len(df_app)
# Out:
# 9659

# %% [markdown]
# # Fake User Details Dataset

# %%
from faker import Faker
fake = Faker()
n = 1000
faker_data = pd.DataFrame([[fake.name(), np.random.randint(14,65), fake.state()] for _ in range(n)],
     columns=['user_name', 'user_age', 'user_location'])
user_id = pd.factorize(faker_data.apply(tuple, axis=1))[0] + 1
faker_data.insert(loc=0, column='user_id', value=user_id)
faker_data.head(30)
# Out:
#     user_id             user_name  user_age   user_location
# 0   1        Lynn West             35        Kansas
# 1   2        Keith Wyatt           19        Connecticut
# 2   3        Jacqueline Velazquez  19        Kansas
# 3   4        Angela Trujillo       62        Illinois
# 4   5        Stephanie Cantrell    53        South Carolina
# 5   6        Gary Morris           41        Tennessee
# 6   7        Rachel Hobbs          14        Indiana
# 7   8        Perry Mclaughlin      22        Maryland
# 8   9        Stephanie Morris      14        New Mexico
# 9   10       Katie Hill            17        Oregon
# 10  11       Christopher Mcbride   44        Georgia
# 11  12       Aaron Murphy          27        Arkansas
# 12  13       Kathryn Collins       59        Massachusetts
# 13  14       Christopher Rose      46        Texas
# 14  15       Jimmy Washington      46        Pennsylvania
# 15  16       Christopher Clark     17        Mississippi
# 16  17       Marissa Mccullough    37        Oklahoma
# 17  18       Marc White            22        Nebraska
# 18  19       Carlos Alvarez        59        Indiana
# 19  20       Jeffrey Beck          43        Vermont
# 20  21       Brittney Ferguson     34        Idaho
# 21  22       Joseph Lewis          62        West Virginia
# 22  23       Kim Roach             59        Kansas
# 23  24       Douglas Ortiz         22        Virginia
# 24  25       Kimberly Valdez       36        West Virginia
# 25  26       Denise Taylor         31        Georgia
# 26  27       Dominique Bailey      33        Idaho
# 27  28       Albert Franklin       26        Illinois
# 28  29       Lisa Smith            35        South Dakota
# 29  30       Lee Jenkins           28        North Dakota

# %% [markdown]
# # Data Merge (Kaggle Google App Data + Fake User Details Data)

# %%
#Merge Faker data to kaggle data on left
users_app_data = df.merge(faker_data, on='user_id', how='left')
#Add time spent column
#users_app_data['time_spent_min'] = np.random.randint(90, 400, len(users_app_data)) #only used in batch processing
#users_app_data['user_details'] = users_app_data['user_name'] + ', ' + users_app_data['user_age'].astype(str) + ', ' + users_app_data['user_location']
#users_app_data = users_app_data.drop(['user_name', 'user_age', 'user_location'], 1)
users_app_data
# Out:
#       download_date  user_id  \
# 0     2021-03-28     450
# 1     2021-03-28     589
# 2     2021-03-28     983
# 3     2021-03-28     951
# 4     2021-03-28     30
# ...          ...     ..
# 10834 2021-03-28     377
# 10835 2021-03-28     438
# 10836 2021-03-28     475
# 10837 2021-03-28     632
# 10838 2021-03-28     220
#
#                                                                                  app  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook
# 1      CE-SETRAM l’Appli
# 2      CE KISIO
# 3      Terminal Emulator for Android
# 4      Ceasa CE
# ...         ...
# 10834  Rainbow - Journal & Activities
# 10835  Classical music for baby
# 10836  How do I care about my child?
# 10837  Kids Fang - Infant Videos, Children's Songs, Fairy Tales, Lullaby Collections
# 10838  iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  category  rating  reviews app_size     installs app_type  \
# 0      ART_AND_DESIGN      4.1     159      19M      10,000+      Free
# 1      LIBRARIES_AND_DEMO NaN      0        2.6M     100+         Free
# 2      LIFESTYLE          NaN      1        24M      100+         Free
# 3      TOOLS               4.4     113951   551k     10,000,000+  Free
# 4      TOOLS              NaN      0        4.0M     50+          Free
# ...      ...               ..     ..         ...     ...           ...
# 10834  PARENTING           4.8     6668     20M      100,000+     Free
# 10835  PARENTING           4.8     1940     38M      100,000+     Free
# 10836  PARENTING          NaN      34       4.9M     10,000+      Free
# 10837  PARENTING           4.6     349      4.4M     100,000+     Free
# 10838  LIFESTYLE           4.5     398307   19M      10,000,000+  Free
#
#       price content_rating                   genres      last_updated  \
# 0      0     Everyone       Art & Design             January 7, 2018
# 1      0     Everyone       Libraries & Demo         December 5, 2017
# 2      0     Everyone       Lifestyle                February 5, 2018
# 3      0     Everyone       Tools                    April 15, 2015
# 4      0     Everyone       Tools                    June 13, 2018
# ...   ..          ...         ...                              ...
# 10834  0     Everyone       Parenting                March 28, 2018
# 10835  0     Everyone       Parenting;Music & Video  July 18, 2018
# 10836  0     Everyone       Parenting                July 3, 2018
# 10837  0     Everyone       Parenting                March 21, 2018
# 10838  0     Everyone       Lifestyle                July 25, 2018
#
#           current_version     android_version  app_id  \
# 0      1.0.0               4.0.3 and up        7462
# 1      1.1.8               4.0.3 and up        2470
# 2      1.0.1               4.1 and up          2464
# 3      1.0.70              1.6 and up          8812
# 4      1.0                 4.0 and up          2944
# ...    ...                        ...           ...
# 10834  2.5.9               4.1 and up          7838
# 10835  1.04                4.2 and up          3070
# 10836  1.2                 4.0 and up          5764
# 10837  1.7                 4.4 and up          6088
# 10838  Varies with device  Varies with device  9986
#
#                         user_details
# 0      Shannon Holmes, 46, Iowa
# 1      Kelly Anderson, 19, Maryland
# 2      Alyssa Brown, 23, Missouri
# 3      Timothy Francis, 50, New York
# 4      Lee Jenkins, 28, North Dakota
# ...                              ...
# 10834  Dale Morgan, 32, Nevada
# 10835  Jeanne Navarro, 37, Iowa
# 10836  Anthony Long MD, 63, Nebraska
# 10837  Antonio Torres, 55, Florida
# 10838  Bobby Lopez, 53, Kansas
#
# [10839 rows x 17 columns]

# %%
#Check Total Duplicates
(users_app_data.duplicated().value_counts()/users_app_data.shape[0])*100
# Out:
# False    100.0
# dtype: float64

# %%
# Fill Nan in rating data
rating_data=users_app_data[pd.notnull(users_app_data['rating'])]
median=np.median(rating_data['rating'])
users_app_data['rating'].fillna(median,inplace=True)

users_app_data.dropna(inplace=True)

# %% [markdown]
# # Data Preprocessing

# %%
# converting last date
users_app_data['last_updated']=pd.to_datetime(users_app_data['last_updated'])
users_app_data['last_updated'] = users_app_data['last_updated'].dt.strftime('%Y-%m-%d')
users_app_data['last_updated'] = users_app_data['last_updated'].astype('datetime64[ns]')

# %%
# convert datatype to integer
users_app_data['rating'] = pd.to_numeric(users_app_data['rating'], errors='coerce')
users_app_data['reviews'] = pd.to_numeric(users_app_data['reviews'], errors='coerce')
users_app_data['installs'] = users_app_data['installs'].str.replace(',','').str.replace('+','').astype('int')
users_app_data['app_size'] = users_app_data['app_size'].str.replace('M','e+6').str.replace('k','e+3').str.replace('Varies with device','0').astype('float')
users_app_data['price'] = users_app_data['price'].str.replace('$','').astype('float')

# %%
users_app_data.dtypes
# Out:
# download_date      datetime64[ns]
# user_id            int64
# app                object
# category           object
# rating             float64
# reviews            int64
# app_size           float64
# installs           int64
# app_type           object
# price              float64
# content_rating     object
# genres             object
# last_updated       datetime64[ns]
# current_version    object
# android_version    object
# app_id             int64
# user_details       object
# dtype: object

# %%
users_app_data.index.names = ['event_id']
users_app_data = users_app_data[0:2000]
users_app_data.to_csv('users_app_data_stream.csv')
